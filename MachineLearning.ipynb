# %% [markdown]
# ### Machine Learning - Final Project

# %%
#Libraries
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# %%
# Read and clean the data

# Read the data using a raw string (r'...') to avoid escape sequence issues
df = pd.read_csv('C:\\Users\\DELL\\Desktop\\DataSetNvidiaK\\NVDA.csv')

# Show the data
df
# Out:
#             Date   Adj Close       Close        High         Low        Open  \
# 0     1999-01-22    0.037615    0.041016    0.048828    0.038802    0.043750
# 1     1999-01-25    0.041556    0.045313    0.045833    0.041016    0.044271
# 2     1999-01-26    0.038331    0.041797    0.046745    0.041146    0.045833
# 3     1999-01-27    0.038212    0.041667    0.042969    0.039583    0.041927
# 4     1999-01-28    0.038092    0.041536    0.041927    0.041276    0.041667
# ...          ...         ...         ...         ...         ...         ...
# 6553  2025-02-10  133.570007  133.570007  135.000000  129.960007  130.089996
# 6554  2025-02-11  132.800003  132.800003  134.479996  131.020004  132.580002
# 6555  2025-02-12  131.139999  131.139999  132.240005  129.080002  130.020004
# 6556  2025-02-13  135.289993  135.289993  136.500000  131.169998  131.559998
# 6557  2025-02-14  138.850006  138.850006  139.250000  135.500000  136.479996
#
#           Volume
# 0     2714688000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6558 entries, 0 to 6557
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6558 non-null   object
#  1   Adj Close  6558 non-null   float64
#  2   Close      6558 non-null   float64
#  3   High       6558 non-null   float64
#  4   Low        6558 non-null   float64
#  5   Open       6558 non-null   float64
#  6   Volume     6558 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 358.8+ KB

# %%
# Set Date as index - better time series handling
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
df.describe()
# Out:
#          Adj Close        Close         High          Low         Open  \
# count  6558.000000  6558.000000  6558.000000  6558.000000  6558.000000
# mean      8.768532     8.795447     8.956567     8.618315     8.795850
# std      23.907205    23.904882    24.349618    23.419200    23.922708
# min       0.031286     0.034115     0.035547     0.033333     0.034896
# 25%       0.257739     0.281042     0.288511     0.273354     0.280810
# 50%       0.437176     0.466083     0.472875     0.459250     0.466584
# 75%       4.597059     4.644625     4.724000     4.588750     4.632437
# max     149.429993   149.429993   153.130005   147.820007   153.029999
#
#              Volume
# count  6.558000e+03
# mean   5.991103e+08
# std    4.307236e+08
# min    1.968000e+07
# 25%    3.384780e+08
# 50%    5.002635e+08
# 75%    7.307002e+08
# max    9.230856e+09

# %%
# Feature Distribution 
df.hist(figsize=(10, 8), bins=30)
plt.suptitle("Feature Distributions")
plt.show()

# %%
import pandas as pd
import numpy as np

# Assuming df is your DataFrame
# Calculate descriptive statistics
desc_stats = pd.DataFrame({
    'Mean': df.mean(),
    'Mode': df.mode().iloc[0],  # Takes the first mode if multimodal
    'Range': df.max() - df.min(),
    'Std Dev': df.std(),
    'Variance': df.var(),
    'Min': df.min(),
    'Max': df.max()
})

# Transpose for better readability (statistics as rows)
desc_stats = desc_stats.T

# Display the statistics
print("Descriptive Statistics for All Columns:")
print(desc_stats)
# Out:
# Descriptive Statistics for All Columns:
#            Adj Close       Close        High         Low        Open  \
# Mean        8.768532    8.795447    8.956567    8.618315    8.795850
# Mode        0.040122    0.361000    0.357500    0.359500    0.039583
# Range     149.398706  149.395878  153.094458  147.786674  152.995103
# Std Dev    23.907205   23.904882   24.349618   23.419200   23.922708
# Variance  571.554435  571.443401  592.903894  548.458913  572.295937
# Min         0.031286    0.034115    0.035547    0.033333    0.034896
# Max       149.429993  149.429993  153.130005  147.820007  153.029999
#
#                 Volume
# Mean      5.991103e+08
# Mode      4.517280e+08
# Range     9.211176e+09
# Std Dev   4.307236e+08
# Variance  1.855228e+17
# Min       1.968000e+07
# Max       9.230856e+09

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
desc_stats = np.random.normal(50, 10, 1000)  # Normally distributed data

# Calculate mean
mean = np.mean(desc_stats)

# Plot histogram
plt.hist(desc_stats, bins=30, edgecolor='black')

# Add mean line
plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f'Mean = {mean:.2f}')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Mean')
plt.legend()
plt.show()

# %%
# Feature Distribution 
df.hist(figsize=(10, 8), bins=30)
plt.suptitle("Feature Distributions")
plt.show()

# %%
# Feature Distribution 
df.hist(figsize=(10, 8), bins=30)
plt.suptitle("Feature Distributions")
plt.show()

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(10, 8), bins=30)
plt.suptitle("Feature Distributions")

# Create a separate figure for the statistics table
fig, ax = plt.subplots(figsize=(12, 2))
ax.axis('off')
table = ax.table(cellText=desc_stats.values,
                 colLabels=desc_stats.columns,
                 rowLabels=desc_stats.index,
                 cellLoc='center',
                 loc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)
plt.title("Descriptive Statistics", y=1.1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 9
#       7 fig, ax = plt.subplots(figsize=(12, 2))
#       8 ax.axis('off')
# ----> 9 table = ax.table(cellText=desc_stats.values,
#      10                  colLabels=desc_stats.columns,
#      11                  rowLabels=desc_stats.index,
#      12                  cellLoc='center',
#      13                  loc='center')
#      14 table.auto_set_font_size(False)
#      15 table.set_fontsize(10)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data from your table
data = {
    'Adj Close': [8.768, 0.040, 149.399, 23.907, 571.554, 0.031, 149.430],
    'Close': [8.795, 0.361, 149.396, 23.905, 571.443, 0.034, 149.430],
    'High': [8.957, 0.357, 153.094, 24.350, 592.904, 0.036, 153.130],
    'Low': [8.618, 0.359, 147.787, 23.419, 548.459, 0.033, 147.820],
    'Open': [8.796, 0.040, 153.995, 23.923, 572.296, 0.035, 153.030],
    'Volume': [599110328.7, 451728000.0, 9211176000.0, 430723588.8, 1.855e+17, 19680000.0, 9230856000.0]
}

stats = pd.DataFrame(data, index=['Mean', 'Mode', 'Range', 'Std Dev', 'Variance', 'Min', 'Max'])

# Plot settings
plt.figure(figsize=(15, 12))
plt.suptitle('Descriptive Statistics Comparison', y=1.02, fontsize=16)

# Plot Mean and Mode
plt.subplot(2, 2, 1)
stats.loc[['Mean', 'Mode']].T.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Mean vs Mode')
plt.ylabel('Value')
plt.xticks(rotation=45)

# Plot Range, Min, Max
plt.subplot(2, 2, 2)
stats.loc[['Range', 'Min', 'Max']].T.plot(kind='bar', color=['lightgreen', 'lightblue', 'orange'])
plt.title('Range, Min, and Max')
plt.xticks(rotation=45)

# Plot Std Dev and Variance (log scale for variance)
plt.subplot(2, 2, 3)
stats.loc[['Std Dev']].T.plot(kind='bar', color='gold', legend=False)
plt.title('Standard Deviation')
plt.xticks(rotation=45)

ax2 = plt.subplot(2, 2, 4)
stats.loc[['Variance']].T.plot(kind='bar', color='orchid', ax=ax2, legend=False)
plt.yscale('log')  # Log scale due to huge variance values
plt.title('Variance (Log Scale)')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# Volume-specific plot (separate due to scale differences)
vol_stats = stats['Close'].drop('Variance')  # Exclude extreme variance
plt.figure(figsize=(10, 5))
vol_stats.plot(kind='bar', color='purple')
plt.title('Close Statistics (Excluding Variance)')
plt.ylabel('Count')
plt.yscale('log')  # Log scale for better visibility
plt.show()

# %%
# Volume-specific plot (separate due to scale differences)
vol_stats = stats['Volume'].drop('Variance')  # Exclude extreme variance
plt.figure(figsize=(10, 5))
vol_stats.plot(kind='bar', color='green')
plt.title('Volume Statistics (Excluding Variance)')
plt.ylabel('Count')
plt.yscale('log')  # Log scale for better visibility
plt.show()


# Volume-specific plot (separate due to scale differences)
low_stats = stats['Low'].drop('Variance')  # Exclude extreme variance
plt.figure(figsize=(10, 5))
low_stats.plot(kind='bar', color='purple')
plt.title('Low Statistics (Excluding Variance)')
plt.ylabel('Count')
plt.yscale('log')  # Log scale for better visibility
plt.show()

# Volume-specific plot (separate due to scale differences)
hight_stats = stats['High'].drop('Variance')  # Exclude extreme variance
plt.figure(figsize=(10, 5))
hight_stats.plot(kind='bar', color='pink')
plt.title('High Statistics (Excluding Variance)')
plt.ylabel('Count')
plt.yscale('log')  # Log scale for better visibility
plt.show()

# %%
# Volume-specific plot (separate due to scale differences)
low_stats = stats['Low'].drop('Variance')  # Exclude extreme variance
plt.figure(figsize=(10, 5))
low_stats.plot(kind='bar', color='purple')
plt.title('Low Statistics (Excluding Variance)')
plt.ylabel('Count')
plt.yscale('log')  # Log scale for better visibility
plt.show()

# %%
# Focus on price columns only (excluding Volume)
price_cols = ['Adj Close', 'Close', 'High', 'Low', 'Open']
plt.figure(figsize=(12, 6))
stats.loc[['Mean', 'Min', 'Max']].T[price_cols].plot(kind='box')
plt.title('Distribution of Price Metrics')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 4
#       2 price_cols = ['Adj Close', 'Close', 'High', 'Low', 'Open']
#       3 plt.figure(figsize=(12, 6))
# ----> 4 stats.loc[['Mean', 'Min', 'Max']].T[price_cols].plot(kind='box')
#       5 plt.title('Distribution of Price Metrics')
#       6 plt.ylabel('Value')
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
print(df.describe())
# Out:
#          Adj Close        Close         High          Low         Open  \
# count  6558.000000  6558.000000  6558.000000  6558.000000  6558.000000
# mean      8.768532     8.795447     8.956567     8.618315     8.795850
# std      23.907205    23.904882    24.349618    23.419200    23.922708
# min       0.031286     0.034115     0.035547     0.033333     0.034896
# 25%       0.257739     0.281042     0.288511     0.273354     0.280810
# 50%       0.437176     0.466083     0.472875     0.459250     0.466584
# 75%       4.597059     4.644625     4.724000     4.588750     4.632437
# max     149.429993   149.429993   153.130005   147.820007   153.029999
#
#              Volume
# count  6.558000e+03
# mean   5.991103e+08
# std    4.307236e+08
# min    1.968000e+07
# 25%    3.384780e+08
# 50%    5.002635e+08
# 75%    7.307002e+08
# max    9.230856e+09

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Calculate descriptive stats
stats = pd.DataFrame({
    'Mean': df.mean(),
    'Mode': df.mode().iloc[0],
    'Range': df.max() - df.min(),
    'Std Dev': df.std(),
    'Variance': df.var(),
    'Min': df.min(),
    'Max': df.max()
})

# %%
plt.figure(figsize=(15, 10))

# Plot Mean
plt.subplot(2, 3, 1)
stats.loc['Mean'].plot(kind='bar', color='skyblue', title='Mean Values')

# Plot Mode
plt.subplot(2, 3, 2)
stats.loc['Mode'].plot(kind='bar', color='salmon', title='Mode Values')

# Plot Range
plt.subplot(2, 3, 3)
stats.loc['Range'].plot(kind='bar', color='lightgreen', title='Range (Max - Min)')

# Plot Standard Deviation
plt.subplot(2, 3, 4)
stats.loc['Std Dev'].plot(kind='bar', color='gold', title='Standard Deviation')

# Plot Variance
plt.subplot(2, 3, 5)
stats.loc['Variance'].plot(kind='bar', color='orchid', title='Variance')

# Plot Min & Max Together
plt.subplot(2, 3, 6)
df_stats_minmax = stats.loc[['Min', 'Max']].T
df_stats_minmax.plot(kind='bar', color=['lightblue', 'orange'], title='Min vs Max')

plt.tight_layout()
plt.suptitle('Descriptive Statistics Across Columns', y=1.02, fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Mean'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 5
#       3 # Plot Mean
# ...

# %%
# Time-Series Plot of Closing Price

plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Close'], label='Close Price')
plt.title('NVIDIA Stock Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()
