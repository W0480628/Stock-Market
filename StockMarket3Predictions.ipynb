# %% [markdown]
# ### Stock Market Predictions NVIDIA

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
from sklearn import metrics 
dat = yf.Ticker("NVDA")
df = yf.download(["NVDA"], period='120mo', interval='1d') # Por hora o por minuto, o por dia 
df[('Prev Close', 'NVDA')] = df[('Close', 'NVDA')].shift(1)  # Shifted by 1 to use previous day's close to predict today's
df.dropna(inplace=True)  # Remove rows with NaN values
df.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume  \
# Ticker            NVDA        NVDA        NVDA        NVDA       NVDA
# Date
# 2025-04-08   96.300003  105.849998   94.459999  103.809998  476243400
# 2025-04-09  114.330002  115.099998   97.529999   98.889999  612918300
# 2025-04-10  107.570000  110.860001   99.150002  109.370003  437812400
# 2025-04-11  110.930000  111.550003  107.480003  108.500000  312853800
# 2025-04-14  110.709999  114.290001  109.070000  114.139999  259339786
#
# Price       Prev Close
# Ticker            NVDA
# Date
# 2025-04-08   97.639999
# 2025-04-09   96.300003
# 2025-04-10  114.330002
# 2025-04-11  107.570000
# 2025-04-14  110.930000

# %%
import pyodbc 


try:
    with pyodbc.connect(r'DRIVER={ODBC Driver 17 for SQL Server};SERVER=localhost;DATABASE=stock_market;Trusted_Connection=yes;')  as conn: # Si se pierde la conexion, cierra la sesion
        cursor = conn.cursor()
        # Method 2: Using itertuples() - faster than iterrows()
        for row in df.itertuples():
            print(f"Index: {row.Index}")
            print(row)
            
            data = {
                'ticker': 'NVDA',
                'date': row.Index,
                'close': row[1],
                'high': row[2],
                'low': row[3],
                'open': row[4],
                'volume': row[5]
            }
            print(data)
            cursor.execute("""
                INSERT INTO StockPrices (Ticker, "Date", "Close", "High", "Low", "Open", Volume)
                SELECT ?, ?, ?, ?, ?, ?, ?
                WHERE NOT EXISTS (
                    SELECT 1 FROM StockPrices 
                    WHERE Ticker = ? AND Date = ?
                )
            """, 
            data['ticker'], data['date'], data['close'], data['high'],
            data['low'], data['open'], data['volume'],
            data['ticker'], data['date'])

            cursor.execute("""
            UPDATE StockPrices
            SET     
                "Close" = COALESCE("Close", ?),
                "High" = COALESCE("High", ?),
                "Low" = COALESCE("Low", ?),
                "Open" = COALESCE("Open", ?),
                "Volume" = COALESCE("Volume", ?)
            WHERE Ticker = ? AND "Date" = ?
            """, data['close'], data['high'],
            data['low'], data['open'], data['volume'], data['ticker'], data["date"])
        
            if cursor.rowcount > 0:
                print("New record inserted successfully")
            else:
                print("Record already exists - no insertion made")
            
except pyodbc.Error as e:
    print(f"Database error: {e}")
# Out:
# Index: 2015-04-16 00:00:00
# Pandas(Index=Timestamp('2015-04-16 00:00:00'), _1=0.5418150424957275, _2=0.5466333129120852, _3=0.5379604146749787, _4=0.5420559387850512, _5=155284000, _6=0.5451875329017639)
# {'ticker': 'NVDA', 'date': Timestamp('2015-04-16 00:00:00'), 'close': 0.5418150424957275, 'high': 0.5466333129120852, 'low': 0.5379604146749787, 'open': 0.5420559387850512, 'volume': 155284000}
# New record inserted successfully
# Index: 2015-04-17 00:00:00
# Pandas(Index=Timestamp('2015-04-17 00:00:00'), _1=0.5348286628723145, _2=0.5401287845910699, _3=0.5302512876351314, _4=0.5304921839828796, _5=293636000, _6=0.5418150424957275)
# {'ticker': 'NVDA', 'date': Timestamp('2015-04-17 00:00:00'), 'close': 0.5348286628723145, 'high': 0.5401287845910699, 'low': 0.5302512876351314, 'open': 0.5304921839828796, 'volume': 293636000}
# New record inserted successfully
# Index: 2015-04-20 00:00:00
# Pandas(Index=Timestamp('2015-04-20 00:00:00'), _1=0.5321784019470215, _2=0.5406103448765697, _3=0.5312147020936703, _4=0.5372375677047504, _5=231624000, _6=0.5348286628723145)
# {'ticker': 'NVDA', 'date': Timestamp('2015-04-20 00:00:00'), 'close': 0.5321784019470215, 'high': 0.5406103448765697, 'low': 0.5312147020936703, 'open': 0.5372375677047504, 'volume': 231624000}
# New record inserted successfully
# Index: 2015-04-21 00:00:00
# Pandas(Index=Timestamp('2015-04-21 00:00:00'), _1=0.5314556360244751, _2=0.538683040026181, _3=0.5288055476837055, _4=0.538683040026181, _5=230456000, _6=0.5321784019470215)
# {'ticker': 'NVDA', 'date': Timestamp('2015-04-21 00:00:00'), 'close': 0.5314556360244751, 'high': 0.538683040026181, 'low': 0.5288055476837055, 'open': 0.538683040026181, 'volume': 230456000}
# New record inserted successfully
# Index: 2015-04-22 00:00:00
# Pandas(Index=Timestamp('2015-04-22 00:00:00'), _1=0.5374783277511597, _2=0.5382010737388766, _3=0.5263962991905525, _4=0.534587401238581, _5=207420000, _6=0.5314556360244751)
# {'ticker': 'NVDA', 'date': Timestamp('2015-04-22 00:00:00'), 'close': 0.5374783277511597, 'high': 0.5382010737388766, 'low': 0.5263962991905525, 'open': 0.534587401238581, 'volume': 207420000}
# New record inserted successfully
# Index: 2015-04-23 00:00:00
# Pandas(Index=Timestamp('2015-04-23 00:00:00'), _1=0.5353102684020996, _2=0.5403694920042017, _3=0.5215782049301528, _4=0.5276010710246478, _5=259380000, _6=0.5374783277511597)
# {'ticker': 'NVDA', 'date': Timestamp('2015-04-23 00:00:00'), 'close': 0.5353102684020996, 'high': 0.5403694920042017, 'low': 0.5215782049301528, 'open': 0.5276010710246478, 'volume': 259380000}
# New record inserted successfully
# Index: 2015-04-24 00:00:00
# Pandas(Index=Timestamp('2015-04-24 00:00:00'), _1=0.5307326912879944, _2=0.5353100052361661, _3=0.5247098281544237, _4=0.5350691090910727, _5=240960000, _6=0.5353102684020996)
# {'ticker': 'NVDA', 'date': Timestamp('2015-04-24 00:00:00'), 'close': 0.5307326912879944, 'high': 0.5353100052361661, 'low': 0.5247098281544237, 'open': 0.5350691090910727, 'volume': 240960000}
# New record inserted successfully
# Index: 2015-04-27 00:00:00
# Pandas(Index=Timestamp('2015-04-27 00:00:00'), _1=0.5348286628723145, _2=0.5442243096944287, _3=0.5278421518426658, _4=0.5324195270798489, _5=248456000, _6=0.5307326912879944)
# {'ticker': 'NVDA', 'date': Timestamp('2015-04-27 00:00:00'), 'close': 0.5348286628723145, 'high': 0.5442243096944287, 'low': 0.5278421518426658, 'open': 0.5324195270798489, 'volume': 248456000}
# New record inserted successfully
# Index: 2015-04-28 00:00:00
# Pandas(Index=Timestamp('2015-04-28 00:00:00'), _1=0.5374783277511597, _2=0.5394056695311676, _3=0.5288054333368458, _4=0.533864655250864, _5=234484000, _6=0.5348286628723145)
# {'ticker': 'NVDA', 'date': Timestamp('2015-04-28 00:00:00'), 'close': 0.5374783277511597, 'high': 0.5394056695311676, 'low': 0.5288054333368458, 'open': 0.533864655250864, 'volume': 234484000}
# New record inserted successfully
# Index: 2015-04-29 00:00:00
# Pandas(Index=Timestamp('2015-04-29 00:00:00'), _1=0.5333829522132874, _2=0.5389239680182708, _3=0.5312147136535187, _4=0.5336238484627157, _5=195156000, _6=0.5374783277511597)
# {'ticker': 'NVDA', 'date': Timestamp('2015-04-29 00:00:00'), 'close': 0.5333829522132874, 'high': 0.5389239680182708, 'low': 0.5312147136535187, 'open': 0.5336238484627157, 'volume': 195156000}
# New record inserted successfully
# Index: 2015-04-30 00:00:00
# Pandas(Index=Timestamp('2015-04-30 00:00:00'), _1=0.5348286628723145, _2=0.5374786950125282, _3=0.529528541153559, _4=0.5307331377689557, _5=218844000, _6=0.5333829522132874)
# {'ticker': 'NVDA', 'date': Timestamp('2015-04-30 00:00:00'), 'close': 0.5348286628723145, 'high': 0.5374786950125282, 'low': 0.529528541153559, 'open': 0.5307331377689557, 'volume': 218844000}
# New record inserted successfully
# Index: 2015-05-01 00:00:00
# Pandas(Index=Timestamp('2015-05-01 00:00:00'), _1=0.5480785369873047, _2=0.5497649250629333, _3=0.5367555553622062, _4=0.5391646893900022, _5=256968000, _6=0.5348286628723145)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-01 00:00:00'), 'close': 0.5480785369873047, 'high': 0.5497649250629333, 'low': 0.5367555553622062, 'open': 0.5391646893900022, 'volume': 256968000}
# New record inserted successfully
# Index: 2015-05-04 00:00:00
# Pandas(Index=Timestamp('2015-05-04 00:00:00'), _1=0.5447058081626892, _2=0.5512105229832674, _3=0.5430194197627124, _4=0.5475967925273907, _5=200720000, _6=0.5480785369873047)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-04 00:00:00'), 'close': 0.5447058081626892, 'high': 0.5512105229832674, 'low': 0.5430194197627124, 'open': 0.5475967925273907, 'volume': 200720000}
# New record inserted successfully
# Index: 2015-05-05 00:00:00
# Pandas(Index=Timestamp('2015-05-05 00:00:00'), _1=0.5307326912879944, _2=0.5435011059904158, _3=0.528323557522222, _4=0.5427783601168562, _5=292928000, _6=0.5447058081626892)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-05 00:00:00'), 'close': 0.5307326912879944, 'high': 0.5435011059904158, 'low': 0.528323557522222, 'open': 0.5427783601168562, 'volume': 292928000}
# New record inserted successfully
# Index: 2015-05-06 00:00:00
# Pandas(Index=Timestamp('2015-05-06 00:00:00'), _1=0.5324192047119141, _2=0.538682965467423, _3=0.5254326979124392, _4=0.5336237431596618, _5=316484000, _6=0.5307326912879944)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-06 00:00:00'), 'close': 0.5324192047119141, 'high': 0.538682965467423, 'low': 0.5254326979124392, 'open': 0.5336237431596618, 'volume': 316484000}
# New record inserted successfully
# Index: 2015-05-07 00:00:00
# Pandas(Index=Timestamp('2015-05-07 00:00:00'), _1=0.5418150424957275, _2=0.5435014313976213, _3=0.5285647701315872, _4=0.530251159033481, _5=534564000, _6=0.5324192047119141)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-07 00:00:00'), 'close': 0.5418150424957275, 'high': 0.5435014313976213, 'low': 0.5285647701315872, 'open': 0.530251159033481, 'volume': 534564000}
# New record inserted successfully
# Index: 2015-05-08 00:00:00
# Pandas(Index=Timestamp('2015-05-08 00:00:00'), _1=0.5018233060836792, _2=0.5261556107764161, _3=0.493632258239448, _4=0.5061597837223744, _5=1146552000, _6=0.5418150424957275)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-08 00:00:00'), 'close': 0.5018233060836792, 'high': 0.5261556107764161, 'low': 0.493632258239448, 'open': 0.5061597837223744, 'volume': 1146552000}
# New record inserted successfully
# Index: 2015-05-11 00:00:00
# Pandas(Index=Timestamp('2015-05-11 00:00:00'), _1=0.4970049560070038, _2=0.5020641791056679, _3=0.49098214795013995, _4=0.4948367175361477, _5=544144000, _6=0.5018233060836792)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-11 00:00:00'), 'close': 0.4970049560070038, 'high': 0.5020641791056679, 'low': 0.49098214795013995, 'open': 0.4948367175361477, 'volume': 544144000}
# New record inserted successfully
# Index: 2015-05-12 00:00:00
# Pandas(Index=Timestamp('2015-05-12 00:00:00'), _1=0.5018233060836792, _2=0.5059188300057949, _3=0.4931504082446003, _4=0.4933913619611799, _5=388800000, _6=0.4970049560070038)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-12 00:00:00'), 'close': 0.5018233060836792, 'high': 0.5059188300057949, 'low': 0.4931504082446003, 'open': 0.4933913619611799, 'volume': 388800000}
# New record inserted successfully
# Index: 2015-05-13 00:00:00
# Pandas(Index=Timestamp('2015-05-13 00:00:00'), _1=0.5047142505645752, _2=0.5092916241132226, _3=0.49989598075704333, _4=0.5054369967795357, _5=308524000, _6=0.5018233060836792)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-13 00:00:00'), 'close': 0.5047142505645752, 'high': 0.5092916241132226, 'low': 0.49989598075704333, 'open': 0.5054369967795357, 'volume': 308524000}
# New record inserted successfully
# Index: 2015-05-14 00:00:00
# Pandas(Index=Timestamp('2015-05-14 00:00:00'), _1=0.5129053592681885, _2=0.5155554481870006, _3=0.5049552073883796, _4=0.5061598037038967, _5=293052000, _6=0.5047142505645752)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-14 00:00:00'), 'close': 0.5129053592681885, 'high': 0.5155554481870006, 'low': 0.5049552073883796, 'open': 0.5061598037038967, 'volume': 293052000}
# New record inserted successfully
# Index: 2015-05-15 00:00:00
# Pandas(Index=Timestamp('2015-05-15 00:00:00'), _1=0.5131461024284363, _2=0.5174825210205891, _3=0.510014222219213, _4=0.5150733868164398, _5=215824000, _6=0.5129053592681885)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-15 00:00:00'), 'close': 0.5131461024284363, 'high': 0.5174825210205891, 'low': 0.510014222219213, 'open': 0.5150733868164398, 'volume': 215824000}
# New record inserted successfully
# Index: 2015-05-18 00:00:00
# Pandas(Index=Timestamp('2015-05-18 00:00:00'), _1=0.5124233961105347, _2=0.5155552765623219, _3=0.5095324118663327, _4=0.5119415462570694, _5=324972000, _6=0.5131461024284363)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-18 00:00:00'), 'close': 0.5124233961105347, 'high': 0.5155552765623219, 'low': 0.5095324118663327, 'open': 0.5119415462570694, 'volume': 324972000}
# New record inserted successfully
# Index: 2015-05-19 00:00:00
# Pandas(Index=Timestamp('2015-05-19 00:00:00'), _1=0.5092286467552185, _2=0.5147953099382049, _3=0.5082604862592649, _4=0.513101057922369, _5=253808000, _6=0.5124233961105347)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-19 00:00:00'), 'close': 0.5092286467552185, 'high': 0.5147953099382049, 'low': 0.5082604862592649, 'open': 0.513101057922369, 'volume': 253808000}
# New record inserted successfully
# Index: 2015-05-20 00:00:00
# Pandas(Index=Timestamp('2015-05-20 00:00:00'), _1=0.5092286467552185, _2=0.5155214014580871, _3=0.5087445665072416, _4=0.5094706580271239, _5=196824000, _6=0.5092286467552185)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-20 00:00:00'), 'close': 0.5092286467552185, 'high': 0.5155214014580871, 'low': 0.5087445665072416, 'open': 0.5094706580271239, 'volume': 196824000}
# New record inserted successfully
# Index: 2015-05-21 00:00:00
# Pandas(Index=Timestamp('2015-05-21 00:00:00'), _1=0.5055981278419495, _2=0.5116488705391394, _3=0.5051140476526771, _4=0.509470596243652, _5=239692000, _6=0.5092286467552185)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-21 00:00:00'), 'close': 0.5055981278419495, 'high': 0.5116488705391394, 'low': 0.5051140476526771, 'open': 0.509470596243652, 'volume': 239692000}
# New record inserted successfully
# Index: 2015-05-22 00:00:00
# Pandas(Index=Timestamp('2015-05-22 00:00:00'), _1=0.5048720836639404, _2=0.508744552428089, _3=0.5036619696337364, _4=0.506808346898097, _5=212592000, _6=0.5055981278419495)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-22 00:00:00'), 'close': 0.5048720836639404, 'high': 0.508744552428089, 'low': 0.5036619696337364, 'open': 0.506808346898097, 'volume': 212592000}
# New record inserted successfully
# Index: 2015-05-26 00:00:00
# Pandas(Index=Timestamp('2015-05-26 00:00:00'), _1=0.5017259120941162, _2=0.505840393810303, _3=0.49785344174235574, _4=0.5024520038915831, _5=259732000, _6=0.5048720836639404)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-26 00:00:00'), 'close': 0.5017259120941162, 'high': 0.505840393810303, 'low': 0.49785344174235574, 'open': 0.5024520038915831, 'volume': 259732000}
# New record inserted successfully
# Index: 2015-05-27 00:00:00
# Pandas(Index=Timestamp('2015-05-27 00:00:00'), _1=0.5285908579826355, _2=0.5310111434688354, _3=0.5034198427628309, _4=0.505114036832755, _5=432332000, _6=0.5017259120941162)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-27 00:00:00'), 'close': 0.5285908579826355, 'high': 0.5310111434688354, 'low': 0.5034198427628309, 'open': 0.505114036832755, 'volume': 432332000}
# New record inserted successfully
# Index: 2015-05-28 00:00:00
# Pandas(Index=Timestamp('2015-05-28 00:00:00'), _1=0.535851776599884, _2=0.5375459708663342, _3=0.5276228165330791, _4=0.5285909192990271, _5=327656000, _6=0.5285908579826355)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-28 00:00:00'), 'close': 0.535851776599884, 'high': 0.5375459708663342, 'low': 0.5276228165330791, 'open': 0.5285909192990271, 'volume': 327656000}
# New record inserted successfully
# Index: 2015-05-29 00:00:00
# Pandas(Index=Timestamp('2015-05-29 00:00:00'), _1=0.5356098413467407, _2=0.5392402416603036, _3=0.5348837497431936, _4=0.5358518526465322, _5=335168000, _6=0.535851776599884)
# {'ticker': 'NVDA', 'date': Timestamp('2015-05-29 00:00:00'), 'close': 0.5356098413467407, 'high': 0.5392402416603036, 'low': 0.5348837497431936, 'open': 0.5358518526465322, 'volume': 335168000}
# New record inserted successfully
# Index: 2015-06-01 00:00:00
# Pandas(Index=Timestamp('2015-06-01 00:00:00'), _1=0.5416606664657593, _2=0.5469853203537857, _3=0.5356099784924536, _4=0.5389983683738399, _5=372660000, _6=0.5356098413467407)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-01 00:00:00'), 'close': 0.5416606664657593, 'high': 0.5469853203537857, 'low': 0.5356099784924536, 'open': 0.5389983683738399, 'volume': 372660000}
# New record inserted successfully
# Index: 2015-06-02 00:00:00
# Pandas(Index=Timestamp('2015-06-02 00:00:00'), _1=0.5310114622116089, _2=0.5411766904370497, _3=0.5305273817421337, _4=0.5382723230285831, _5=224304000, _6=0.5416606664657593)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-02 00:00:00'), 'close': 0.5310114622116089, 'high': 0.5411766904370497, 'low': 0.5305273817421337, 'open': 0.5382723230285831, 'volume': 224304000}
# New record inserted successfully
# Index: 2015-06-03 00:00:00
# Pandas(Index=Timestamp('2015-06-03 00:00:00'), _1=0.5252026915550232, _2=0.5365780323718018, _3=0.5242345307885118, _4=0.5324635510787659, _5=250788000, _6=0.5310114622116089)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-03 00:00:00'), 'close': 0.5252026915550232, 'high': 0.5365780323718018, 'low': 0.5242345307885118, 'open': 0.5324635510787659, 'volume': 250788000}
# New record inserted successfully
# Index: 2015-06-04 00:00:00
# Pandas(Index=Timestamp('2015-06-04 00:00:00'), _1=0.5346416234970093, _2=0.5363358176396481, _3=0.5220561153469375, _4=0.5220561153469375, _5=323712000, _6=0.5252026915550232)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-04 00:00:00'), 'close': 0.5346416234970093, 'high': 0.5363358176396481, 'low': 0.5220561153469375, 'open': 0.5220561153469375, 'volume': 323712000}
# New record inserted successfully
# Index: 2015-06-05 00:00:00
# Pandas(Index=Timestamp('2015-06-05 00:00:00'), _1=0.538756251335144, _2=0.5411765375905652, _3=0.5273808540009067, _4=0.5329475181587927, _5=313320000, _6=0.5346416234970093)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-05 00:00:00'), 'close': 0.538756251335144, 'high': 0.5411765375905652, 'low': 0.5273808540009067, 'open': 0.5329475181587927, 'volume': 313320000}
# New record inserted successfully
# Index: 2015-06-08 00:00:00
# Pandas(Index=Timestamp('2015-06-08 00:00:00'), _1=0.5264126658439636, _2=0.5406923697511467, _3=0.5203619800367534, _4=0.5370619698076537, _5=342812000, _6=0.538756251335144)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-08 00:00:00'), 'close': 0.5264126658439636, 'high': 0.5406923697511467, 'low': 0.5203619800367534, 'open': 0.5370619698076537, 'volume': 342812000}
# New record inserted successfully
# Index: 2015-06-09 00:00:00
# Pandas(Index=Timestamp('2015-06-09 00:00:00'), _1=0.529075026512146, _2=0.5329474377733963, _3=0.5259286490842546, _4=0.5268967518995672, _5=256888000, _6=0.5264126658439636)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-09 00:00:00'), 'close': 0.529075026512146, 'high': 0.5329474377733963, 'low': 0.5259286490842546, 'open': 0.5268967518995672, 'volume': 256888000}
# New record inserted successfully
# Index: 2015-06-10 00:00:00
# Pandas(Index=Timestamp('2015-06-10 00:00:00'), _1=0.5196359753608704, _2=0.5261707425147331, _3=0.5167316087572974, _4=0.5227823532800155, _5=529460000, _6=0.529075026512146)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-10 00:00:00'), 'close': 0.5196359753608704, 'high': 0.5261707425147331, 'low': 0.5167316087572974, 'open': 0.5227823532800155, 'volume': 529460000}
# New record inserted successfully
# Index: 2015-06-11 00:00:00
# Pandas(Index=Timestamp('2015-06-11 00:00:00'), _1=0.5252026915550232, _2=0.5288330924648035, _3=0.5196360268164023, _4=0.5196360268164023, _5=283052000, _6=0.5196359753608704)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-11 00:00:00'), 'close': 0.5252026915550232, 'high': 0.5288330924648035, 'low': 0.5196360268164023, 'open': 0.5196360268164023, 'volume': 283052000}
# New record inserted successfully
# Index: 2015-06-12 00:00:00
# Pandas(Index=Timestamp('2015-06-12 00:00:00'), _1=0.5109229683876038, _2=0.5249606066270835, _3=0.5097127963181729, _4=0.5218142284915798, _5=323728000, _6=0.5252026915550232)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-12 00:00:00'), 'close': 0.5109229683876038, 'high': 0.5249606066270835, 'low': 0.5097127963181729, 'open': 0.5218142284915798, 'volume': 323728000}
# New record inserted successfully
# Index: 2015-06-15 00:00:00
# Pandas(Index=Timestamp('2015-06-15 00:00:00'), _1=0.509954571723938, _2=0.5123748567650249, _3=0.5043879103590232, _4=0.5082603202614447, _5=306548000, _6=0.5109229683876038)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-15 00:00:00'), 'close': 0.509954571723938, 'high': 0.5123748567650249, 'low': 0.5043879103590232, 'open': 0.5082603202614447, 'volume': 306548000}
# New record inserted successfully
# Index: 2015-06-16 00:00:00
# Pandas(Index=Timestamp('2015-06-16 00:00:00'), _1=0.516247570514679, _2=0.5169736622247747, _3=0.5039041268514132, _4=0.5089867111179024, _5=256892000, _6=0.509954571723938)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-16 00:00:00'), 'close': 0.516247570514679, 'high': 0.5169736622247747, 'low': 0.5039041268514132, 'open': 0.5089867111179024, 'volume': 256892000}
# New record inserted successfully
# Index: 2015-06-17 00:00:00
# Pandas(Index=Timestamp('2015-06-17 00:00:00'), _1=0.5222982168197632, _2=0.5252025831112398, _3=0.5147953475056756, _4=0.5160054616576774, _5=233544000, _6=0.516247570514679)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-17 00:00:00'), 'close': 0.5222982168197632, 'high': 0.5252025831112398, 'low': 0.5147953475056756, 'open': 0.5160054616576774, 'volume': 233544000}
# New record inserted successfully
# Index: 2015-06-18 00:00:00
# Pandas(Index=Timestamp('2015-06-18 00:00:00'), _1=0.5310114622116089, _2=0.5343998523853584, _3=0.525202785098868, _4=0.5266549688031013, _5=299404000, _6=0.5222982168197632)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-18 00:00:00'), 'close': 0.5310114622116089, 'high': 0.5343998523853584, 'low': 0.525202785098868, 'open': 0.5266549688031013, 'volume': 299404000}
# New record inserted successfully
# Index: 2015-06-19 00:00:00
# Pandas(Index=Timestamp('2015-06-19 00:00:00'), _1=0.5293168425559998, _2=0.5353675261980865, _3=0.5244762725606719, _4=0.5310110362839499, _5=355656000, _6=0.5310114622116089)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-19 00:00:00'), 'close': 0.5293168425559998, 'high': 0.5353675261980865, 'low': 0.5244762725606719, 'open': 0.5310110362839499, 'volume': 355656000}
# New record inserted successfully
# Index: 2015-06-22 00:00:00
# Pandas(Index=Timestamp('2015-06-22 00:00:00'), _1=0.5271390080451965, _2=0.5331897544338997, _3=0.519152055126457, _4=0.5302853869346511, _5=514236000, _6=0.5293168425559998)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-22 00:00:00'), 'close': 0.5271390080451965, 'high': 0.5331897544338997, 'low': 0.519152055126457, 'open': 0.5302853869346511, 'volume': 514236000}
# New record inserted successfully
# Index: 2015-06-23 00:00:00
# Pandas(Index=Timestamp('2015-06-23 00:00:00'), _1=0.5135852098464966, _2=0.532221407579906, _3=0.5094707291290561, _4=0.5281069268624655, _5=414064000, _6=0.5271390080451965)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-23 00:00:00'), 'close': 0.5135852098464966, 'high': 0.532221407579906, 'low': 0.5094707291290561, 'open': 0.5281069268624655, 'volume': 414064000}
# New record inserted successfully
# Index: 2015-06-24 00:00:00
# Pandas(Index=Timestamp('2015-06-24 00:00:00'), _1=0.5085025429725647, _2=0.5155213890260528, _3=0.5060822571993789, _4=0.5128590342826334, _5=253368000, _6=0.5135852098464966)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-24 00:00:00'), 'close': 0.5085025429725647, 'high': 0.5155213890260528, 'low': 0.5060822571993789, 'open': 0.5128590342826334, 'volume': 253368000}
# New record inserted successfully
# Index: 2015-06-25 00:00:00
# Pandas(Index=Timestamp('2015-06-25 00:00:00'), _1=0.5123749375343323, _2=0.5155213143541458, _3=0.5085024693173189, _4=0.5085024693173189, _5=350460000, _6=0.5085025429725647)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-25 00:00:00'), 'close': 0.5123749375343323, 'high': 0.5155213143541458, 'low': 0.5085024693173189, 'open': 0.5085024693173189, 'volume': 350460000}
# New record inserted successfully
# Index: 2015-06-26 00:00:00
# Pandas(Index=Timestamp('2015-06-26 00:00:00'), _1=0.5019676685333252, _2=0.5087445026333252, _3=0.49978945195132407, _4=0.5082604224461257, _5=421296000, _6=0.5123749375343323)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-26 00:00:00'), 'close': 0.5019676685333252, 'high': 0.5087445026333252, 'low': 0.49978945195132407, 'open': 0.5082604224461257, 'volume': 421296000}
# New record inserted successfully
# Index: 2015-06-29 00:00:00
# Pandas(Index=Timestamp('2015-06-29 00:00:00'), _1=0.4869619905948639, _2=0.5012416942117361, _3=0.4862358990800937, _4=0.4961590536083444, _5=391724000, _6=0.5019676685333252)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-29 00:00:00'), 'close': 0.4869619905948639, 'high': 0.5012416942117361, 'low': 0.4862358990800937, 'open': 0.4961590536083444, 'volume': 391724000}
# New record inserted successfully
# Index: 2015-06-30 00:00:00
# Pandas(Index=Timestamp('2015-06-30 00:00:00'), _1=0.4867200255393982, _2=0.49204467854985057, _3=0.4833316362164639, _4=0.48986640354045946, _5=315916000, _6=0.4869619905948639)
# {'ticker': 'NVDA', 'date': Timestamp('2015-06-30 00:00:00'), 'close': 0.4867200255393982, 'high': 0.49204467854985057, 'low': 0.4833316362164639, 'open': 0.48986640354045946, 'volume': 315916000}
# New record inserted successfully
# Index: 2015-07-01 00:00:00
# Pandas(Index=Timestamp('2015-07-01 00:00:00'), _1=0.49373871088027954, _2=0.5058401385579023, _3=0.4893822199979989, _4=0.49882135089779234, _5=302892000, _6=0.4867200255393982)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-01 00:00:00'), 'close': 0.49373871088027954, 'high': 0.5058401385579023, 'low': 0.4893822199979989, 'open': 0.49882135089779234, 'volume': 302892000}
# New record inserted successfully
# Index: 2015-07-02 00:00:00
# Pandas(Index=Timestamp('2015-07-02 00:00:00'), _1=0.49422281980514526, _2=0.49736919695468607, _3=0.49107644265560446, _4=0.49349672833185415, _5=145764000, _6=0.49373871088027954)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-02 00:00:00'), 'close': 0.49422281980514526, 'high': 0.49736919695468607, 'low': 0.49107644265560446, 'open': 0.49349672833185415, 'volume': 145764000}
# New record inserted successfully
# Index: 2015-07-06 00:00:00
# Pandas(Index=Timestamp('2015-07-06 00:00:00'), _1=0.4881720542907715, _2=0.4968850938650217, _3=0.48454165479559363, _4=0.49010831736513794, _5=214776000, _6=0.49422281980514526)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-06 00:00:00'), 'close': 0.4881720542907715, 'high': 0.4968850938650217, 'low': 0.48454165479559363, 'open': 0.49010831736513794, 'volume': 214776000}
# New record inserted successfully
# Index: 2015-07-07 00:00:00
# Pandas(Index=Timestamp('2015-07-07 00:00:00'), _1=0.4789750576019287, _2=0.4872040474525026, _3=0.463727249773355, _4=0.4852678417013892, _5=594252000, _6=0.4881720542907715)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-07 00:00:00'), 'close': 0.4789750576019287, 'high': 0.4872040474525026, 'low': 0.463727249773355, 'open': 0.4852678417013892, 'volume': 594252000}
# New record inserted successfully
# Index: 2015-07-08 00:00:00
# Pandas(Index=Timestamp('2015-07-08 00:00:00'), _1=0.4755866527557373, _2=0.47921708169560284, _3=0.47171418367904694, _4=0.47631274431412735, _5=332492000, _6=0.4789750576019287)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-08 00:00:00'), 'close': 0.4755866527557373, 'high': 0.47921708169560284, 'low': 0.47171418367904694, 'open': 0.47631274431412735, 'volume': 332492000}
# New record inserted successfully
# Index: 2015-07-09 00:00:00
# Pandas(Index=Timestamp('2015-07-09 00:00:00'), _1=0.46977803111076355, _2=0.48526791012030435, _3=0.4668736932225194, _4=0.4830896350650541, _5=357588000, _6=0.4755866527557373)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-09 00:00:00'), 'close': 0.46977803111076355, 'high': 0.48526791012030435, 'low': 0.4668736932225194, 'open': 0.4830896350650541, 'volume': 357588000}
# New record inserted successfully
# Index: 2015-07-10 00:00:00
# Pandas(Index=Timestamp('2015-07-10 00:00:00'), _1=0.47800686955451965, _2=0.4823633894224457, _3=0.4746184523896526, _4=0.4758285951945165, _5=216708000, _6=0.46977803111076355)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-10 00:00:00'), 'close': 0.47800686955451965, 'high': 0.4823633894224457, 'low': 0.4746184523896526, 'open': 0.4758285951945165, 'volume': 216708000}
# New record inserted successfully
# Index: 2015-07-13 00:00:00
# Pandas(Index=Timestamp('2015-07-13 00:00:00'), _1=0.481153279542923, _2=0.4838155765845565, _3=0.4780069022645541, _4=0.48284747381525017, _5=212472000, _6=0.47800686955451965)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-13 00:00:00'), 'close': 0.481153279542923, 'high': 0.4838155765845565, 'low': 0.4780069022645541, 'open': 0.48284747381525017, 'volume': 212472000}
# New record inserted successfully
# Index: 2015-07-14 00:00:00
# Pandas(Index=Timestamp('2015-07-14 00:00:00'), _1=0.4813952147960663, _2=0.48236334626458527, _3=0.47510249008504296, _4=0.48187929495636467, _5=249216000, _6=0.481153279542923)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-14 00:00:00'), 'close': 0.4813952147960663, 'high': 0.48236334626458527, 'low': 0.47510249008504296, 'open': 0.48187929495636467, 'volume': 249216000}
# New record inserted successfully
# Index: 2015-07-15 00:00:00
# Pandas(Index=Timestamp('2015-07-15 00:00:00'), _1=0.47800686955451965, _2=0.4833314921255047, _3=0.47365034968659364, _4=0.48018511506244255, _5=265732000, _6=0.4813952147960663)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-15 00:00:00'), 'close': 0.47800686955451965, 'high': 0.4833314921255047, 'low': 0.47365034968659364, 'open': 0.48018511506244255, 'volume': 265732000}
# New record inserted successfully
# Index: 2015-07-16 00:00:00
# Pandas(Index=Timestamp('2015-07-16 00:00:00'), _1=0.488656222820282, _2=0.488656222820282, _3=0.4792170900998427, _4=0.4809112845310749, _5=282848000, _6=0.47800686955451965)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-16 00:00:00'), 'close': 0.488656222820282, 'high': 0.488656222820282, 'low': 0.4792170900998427, 'open': 0.4809112845310749, 'volume': 282848000}
# New record inserted successfully
# Index: 2015-07-17 00:00:00
# Pandas(Index=Timestamp('2015-07-17 00:00:00'), _1=0.48575183749198914, _2=0.4874460318568008, _3=0.4794590825917357, _4=0.4869620092978076, _5=220372000, _6=0.488656222820282)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-17 00:00:00'), 'close': 0.48575183749198914, 'high': 0.4874460318568008, 'low': 0.4794590825917357, 'open': 0.4869620092978076, 'volume': 220372000}
# New record inserted successfully
# Index: 2015-07-20 00:00:00
# Pandas(Index=Timestamp('2015-07-20 00:00:00'), _1=0.47679686546325684, _2=0.48768818272770226, _3=0.4755867223063283, _4=0.48575191905411014, _5=188412000, _6=0.48575183749198914)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-20 00:00:00'), 'close': 0.47679686546325684, 'high': 0.48768818272770226, 'low': 0.4755867223063283, 'open': 0.48575191905411014, 'volume': 188412000}
# New record inserted successfully
# Index: 2015-07-21 00:00:00
# Pandas(Index=Timestamp('2015-07-21 00:00:00'), _1=0.4789750576019287, _2=0.48575186428708206, _3=0.4758286799782412, _4=0.4758286799782412, _5=149720000, _6=0.47679686546325684)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-21 00:00:00'), 'close': 0.4789750576019287, 'high': 0.48575186428708206, 'low': 0.4758286799782412, 'open': 0.4758286799782412, 'volume': 149720000}
# New record inserted successfully
# Index: 2015-07-22 00:00:00
# Pandas(Index=Timestamp('2015-07-22 00:00:00'), _1=0.46977803111076355, _2=0.47558673573934135, _3=0.46396935533427525, _4=0.47558673573934135, _5=356472000, _6=0.4789750576019287)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-22 00:00:00'), 'close': 0.46977803111076355, 'high': 0.47558673573934135, 'low': 0.46396935533427525, 'open': 0.47558673573934135, 'volume': 356472000}
# New record inserted successfully
# Index: 2015-07-23 00:00:00
# Pandas(Index=Timestamp('2015-07-23 00:00:00'), _1=0.4755866527557373, _2=0.48260547049864355, _3=0.46977794914070176, _4=0.4707460808359166, _5=169916000, _6=0.46977803111076355)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-23 00:00:00'), 'close': 0.4755866527557373, 'high': 0.48260547049864355, 'low': 0.46977794914070176, 'open': 0.4707460808359166, 'volume': 169916000}
# New record inserted successfully
# Index: 2015-07-24 00:00:00
# Pandas(Index=Timestamp('2015-07-24 00:00:00'), _1=0.47001999616622925, _2=0.4794591000073871, _3=0.4680837615995062, _4=0.4789750485787276, _5=188844000, _6=0.4755866527557373)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-24 00:00:00'), 'close': 0.47001999616622925, 'high': 0.4794591000073871, 'low': 0.4680837615995062, 'open': 0.4789750485787276, 'volume': 188844000}
# New record inserted successfully
# Index: 2015-07-27 00:00:00
# Pandas(Index=Timestamp('2015-07-27 00:00:00'), _1=0.46735769510269165, _2=0.47268231880776496, _3=0.4620330713976184, _4=0.4659055118867233, _5=192420000, _6=0.47001999616622925)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-27 00:00:00'), 'close': 0.46735769510269165, 'high': 0.47268231880776496, 'low': 0.4620330713976184, 'open': 0.4659055118867233, 'volume': 192420000}
# New record inserted successfully
# Index: 2015-07-28 00:00:00
# Pandas(Index=Timestamp('2015-07-28 00:00:00'), _1=0.47752293944358826, _2=0.48066928845341184, _3=0.4637272848838306, _4=0.46856785733228234, _5=198308000, _6=0.46735769510269165)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-28 00:00:00'), 'close': 0.47752293944358826, 'high': 0.48066928845341184, 'low': 0.4637272848838306, 'open': 0.46856785733228234, 'volume': 198308000}
# New record inserted successfully
# Index: 2015-07-29 00:00:00
# Pandas(Index=Timestamp('2015-07-29 00:00:00'), _1=0.48333144187927246, _2=0.4872039099930945, _3=0.47461840304921155, _4=0.47655463710612256, _5=232680000, _6=0.47752293944358826)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-29 00:00:00'), 'close': 0.48333144187927246, 'high': 0.4872039099930945, 'low': 0.47461840304921155, 'open': 0.47655463710612256, 'volume': 232680000}
# New record inserted successfully
# Index: 2015-07-30 00:00:00
# Pandas(Index=Timestamp('2015-07-30 00:00:00'), _1=0.48454174399375916, _2=0.48938231601452564, _3=0.4821214291312908, _4=0.4821214291312908, _5=190180000, _6=0.48333144187927246)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-30 00:00:00'), 'close': 0.48454174399375916, 'high': 0.48938231601452564, 'low': 0.4821214291312908, 'open': 0.4821214291312908, 'volume': 190180000}
# New record inserted successfully
# Index: 2015-07-31 00:00:00
# Pandas(Index=Timestamp('2015-07-31 00:00:00'), _1=0.48284751176834106, _2=0.4867199520020326, _3=0.4799431743800513, _4=0.48647794071672446, _5=218340000, _6=0.48454174399375916)
# {'ticker': 'NVDA', 'date': Timestamp('2015-07-31 00:00:00'), 'close': 0.48284751176834106, 'high': 0.4867199520020326, 'low': 0.4799431743800513, 'open': 0.48647794071672446, 'volume': 218340000}
# New record inserted successfully
# Index: 2015-08-03 00:00:00
# Pandas(Index=Timestamp('2015-08-03 00:00:00'), _1=0.4910765290260315, _2=0.4915605516239139, _3=0.48042725286629206, _4=0.4867199794200558, _5=397132000, _6=0.48284751176834106)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-03 00:00:00'), 'close': 0.4910765290260315, 'high': 0.4915605516239139, 'low': 0.48042725286629206, 'open': 0.4867199794200558, 'volume': 397132000}
# New record inserted successfully
# Index: 2015-08-04 00:00:00
# Pandas(Index=Timestamp('2015-08-04 00:00:00'), _1=0.49301275610923767, _2=0.4944649393739202, _3=0.4874460920640711, _4=0.4893823556517061, _5=260100000, _6=0.4910765290260315)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-04 00:00:00'), 'close': 0.49301275610923767, 'high': 0.4944649393739202, 'low': 0.4874460920640711, 'open': 0.4893823556517061, 'volume': 260100000}
# New record inserted successfully
# Index: 2015-08-05 00:00:00
# Pandas(Index=Timestamp('2015-08-05 00:00:00'), _1=0.49809515476226807, _2=0.505598021033971, _3=0.49712699458824783, _4=0.5051139409469608, _5=234628000, _6=0.49301275610923767)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-05 00:00:00'), 'close': 0.49809515476226807, 'high': 0.505598021033971, 'low': 0.49712699458824783, 'open': 0.5051139409469608, 'volume': 234628000}
# New record inserted successfully
# Index: 2015-08-06 00:00:00
# Pandas(Index=Timestamp('2015-08-06 00:00:00'), _1=0.4949491322040558, _2=0.5005157975145844, _3=0.48672011106836915, _4=0.49688533852763617, _5=655676000, _6=0.49809515476226807)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-06 00:00:00'), 'close': 0.4949491322040558, 'high': 0.5005157975145844, 'low': 0.48672011106836915, 'open': 0.49688533852763617, 'volume': 655676000}
# New record inserted successfully
# Index: 2015-08-07 00:00:00
# Pandas(Index=Timestamp('2015-08-07 00:00:00'), _1=0.5561823844909668, _2=0.5656214613263699, _3=0.5295591756299575, _4=0.543596871771521, _5=1405248000, _6=0.4949491322040558)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-07 00:00:00'), 'close': 0.5561823844909668, 'high': 0.5656214613263699, 'low': 0.5295591756299575, 'open': 0.543596871771521, 'volume': 1405248000}
# New record inserted successfully
# Index: 2015-08-10 00:00:00
# Pandas(Index=Timestamp('2015-08-10 00:00:00'), _1=0.575544536113739, _2=0.5796590163385341, _3=0.5489213337346726, _4=0.552309780129357, _5=662304000, _6=0.5561823844909668)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-10 00:00:00'), 'close': 0.575544536113739, 'high': 0.5796590163385341, 'low': 0.5489213337346726, 'open': 0.552309780129357, 'volume': 662304000}
# New record inserted successfully
# Index: 2015-08-11 00:00:00
# Pandas(Index=Timestamp('2015-08-11 00:00:00'), _1=0.5726402401924133, _2=0.5782069041683346, _3=0.567073576216492, _4=0.567073576216492, _5=435008000, _6=0.575544536113739)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-11 00:00:00'), 'close': 0.5726402401924133, 'high': 0.5782069041683346, 'low': 0.567073576216492, 'open': 0.567073576216492, 'volume': 435008000}
# New record inserted successfully
# Index: 2015-08-12 00:00:00
# Pandas(Index=Timestamp('2015-08-12 00:00:00'), _1=0.5740923881530762, _2=0.578206868629487, _3=0.5634431411727086, _4=0.5634431411727086, _5=384048000, _6=0.5726402401924133)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-12 00:00:00'), 'close': 0.5740923881530762, 'high': 0.578206868629487, 'low': 0.5634431411727086, 'open': 0.5634431411727086, 'volume': 384048000}
# New record inserted successfully
# Index: 2015-08-13 00:00:00
# Pandas(Index=Timestamp('2015-08-13 00:00:00'), _1=0.5692519545555115, _2=0.5760287917034529, _3=0.5677997710449394, _4=0.574818619543248, _5=276884000, _6=0.5740923881530762)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-13 00:00:00'), 'close': 0.5692519545555115, 'high': 0.5760287917034529, 'low': 0.5677997710449394, 'open': 0.574818619543248, 'volume': 276884000}
# New record inserted successfully
# Index: 2015-08-14 00:00:00
# Pandas(Index=Timestamp('2015-08-14 00:00:00'), _1=0.5697358250617981, _2=0.5731242135353469, _3=0.5653792761350953, _4=0.5687676646086441, _5=214652000, _6=0.5692519545555115)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-14 00:00:00'), 'close': 0.5697358250617981, 'high': 0.5731242135353469, 'low': 0.5653792761350953, 'open': 0.5687676646086441, 'volume': 214652000}
# New record inserted successfully
# Index: 2015-08-17 00:00:00
# Pandas(Index=Timestamp('2015-08-17 00:00:00'), _1=0.5661053657531738, _2=0.5687676627301459, _3=0.5590865198638876, _4=0.5687676627301459, _5=273880000, _6=0.5697358250617981)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-17 00:00:00'), 'close': 0.5661053657531738, 'high': 0.5687676627301459, 'low': 0.5590865198638876, 'open': 0.5687676627301459, 'volume': 273880000}
# New record inserted successfully
# Index: 2015-08-18 00:00:00
# Pandas(Index=Timestamp('2015-08-18 00:00:00'), _1=0.5609528422355652, _2=0.5682442497651768, _3=0.5565779629496246, _4=0.5643554874933261, _5=287084000, _6=0.5661053657531738)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-18 00:00:00'), 'close': 0.5609528422355652, 'high': 0.5682442497651768, 'low': 0.5565779629496246, 'open': 0.5643554874933261, 'volume': 287084000}
# New record inserted successfully
# Index: 2015-08-19 00:00:00
# Pandas(Index=Timestamp('2015-08-19 00:00:00'), _1=0.5587654709815979, _2=0.5665429964772144, _3=0.552689268323092, _4=0.5602237642553963, _5=249248000, _6=0.5609528422355652)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-19 00:00:00'), 'close': 0.5587654709815979, 'high': 0.5665429964772144, 'low': 0.552689268323092, 'open': 0.5602237642553963, 'volume': 249248000}
# New record inserted successfully
# Index: 2015-08-20 00:00:00
# Pandas(Index=Timestamp('2015-08-20 00:00:00'), _1=0.5385924577713013, _2=0.5551196236163637, _3=0.5359189013369314, _4=0.5524461251289451, _5=426932000, _6=0.5587654709815979)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-20 00:00:00'), 'close': 0.5385924577713013, 'high': 0.5551196236163637, 'low': 0.5359189013369314, 'open': 0.5524461251289451, 'volume': 426932000}
# New record inserted successfully
# Index: 2015-08-21 00:00:00
# Pandas(Index=Timestamp('2015-08-21 00:00:00'), _1=0.5218220949172974, _2=0.543696311091987, _3=0.5213359780457508, _4=0.5347035835704196, _5=382664000, _6=0.5385924577713013)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-21 00:00:00'), 'close': 0.5218220949172974, 'high': 0.543696311091987, 'low': 0.5213359780457508, 'open': 0.5347035835704196, 'volume': 382664000}
# New record inserted successfully
# Index: 2015-08-24 00:00:00
# Pandas(Index=Timestamp('2015-08-24 00:00:00'), _1=0.5033506751060486, _2=0.5305719533057693, _3=0.4860943032352628, _4=0.4926565642759719, _5=682284000, _6=0.5218220949172974)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-24 00:00:00'), 'close': 0.5033506751060486, 'high': 0.5305719533057693, 'low': 0.4860943032352628, 'open': 0.4926565642759719, 'volume': 682284000}
# New record inserted successfully
# Index: 2015-08-25 00:00:00
# Pandas(Index=Timestamp('2015-08-25 00:00:00'), _1=0.4928997755050659, _2=0.5274124699643663, _3=0.4928997755050659, _4=0.5254680593493942, _5=622684000, _6=0.5033506751060486)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-25 00:00:00'), 'close': 0.4928997755050659, 'high': 0.5274124699643663, 'low': 0.4928997755050659, 'open': 0.5254680593493942, 'volume': 622684000}
# New record inserted successfully
# Index: 2015-08-26 00:00:00
# Pandas(Index=Timestamp('2015-08-26 00:00:00'), _1=0.5300857424736023, _2=0.5305718594060123, _3=0.5050519083668845, _4=0.5089406699853259, _5=614976000, _6=0.4928997755050659)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-26 00:00:00'), 'close': 0.5300857424736023, 'high': 0.5305718594060123, 'low': 0.5050519083668845, 'open': 0.5089406699853259, 'volume': 614976000}
# New record inserted successfully
# Index: 2015-08-27 00:00:00
# Pandas(Index=Timestamp('2015-08-27 00:00:00'), _1=0.5500157475471497, _2=0.5502587771008562, _3=0.5325163448471342, _4=0.5356759608331637, _5=463764000, _6=0.5300857424736023)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-27 00:00:00'), 'close': 0.5500157475471497, 'high': 0.5502587771008562, 'low': 0.5325163448471342, 'open': 0.5356759608331637, 'volume': 463764000}
# New record inserted successfully
# Index: 2015-08-28 00:00:00
# Pandas(Index=Timestamp('2015-08-28 00:00:00'), _1=0.5524462461471558, _2=0.5558488918668774, _3=0.5461270138408363, _4=0.5500157766406455, _5=320944000, _6=0.5500157475471497)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-28 00:00:00'), 'close': 0.5524462461471558, 'high': 0.5558488918668774, 'low': 0.5461270138408363, 'open': 0.5500157766406455, 'volume': 320944000}
# New record inserted successfully
# Index: 2015-08-31 00:00:00
# Pandas(Index=Timestamp('2015-08-31 00:00:00'), _1=0.5463699102401733, _2=0.5536613749295128, _3=0.5441825287803213, _4=0.549772613077515, _5=219352000, _6=0.5524462461471558)
# {'ticker': 'NVDA', 'date': Timestamp('2015-08-31 00:00:00'), 'close': 0.5463699102401733, 'high': 0.5536613749295128, 'low': 0.5441825287803213, 'open': 0.549772613077515, 'volume': 219352000}
# New record inserted successfully
# Index: 2015-09-01 00:00:00
# Pandas(Index=Timestamp('2015-09-01 00:00:00'), _1=0.524009644985199, _2=0.5395646945285208, _3=0.5201209405463262, _4=0.5305719641064516, _5=353408000, _6=0.5463699102401733)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-01 00:00:00'), 'close': 0.524009644985199, 'high': 0.5395646945285208, 'low': 0.5201209405463262, 'open': 0.5305719641064516, 'volume': 353408000}
# New record inserted successfully
# Index: 2015-09-02 00:00:00
# Pandas(Index=Timestamp('2015-09-02 00:00:00'), _1=0.5398077368736267, _2=0.5400507664200815, _3=0.5293567130655996, _4=0.5383494437009794, _5=344044000, _6=0.524009644985199)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-02 00:00:00'), 'close': 0.5398077368736267, 'high': 0.5400507664200815, 'low': 0.5293567130655996, 'open': 0.5383494437009794, 'volume': 344044000}
# New record inserted successfully
# Index: 2015-09-03 00:00:00
# Pandas(Index=Timestamp('2015-09-03 00:00:00'), _1=0.5412662029266357, _2=0.5505020240053496, _3=0.5402940264833441, _4=0.5478284663525758, _5=262556000, _6=0.5398077368736267)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-03 00:00:00'), 'close': 0.5412662029266357, 'high': 0.5505020240053496, 'low': 0.5402940264833441, 'open': 0.5478284663525758, 'volume': 262556000}
# New record inserted successfully
# Index: 2015-09-04 00:00:00
# Pandas(Index=Timestamp('2015-09-04 00:00:00'), _1=0.5286275148391724, _2=0.54053683065646, _3=0.5283844853164583, _4=0.5320301599449822, _5=287972000, _6=0.5412662029266357)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-04 00:00:00'), 'close': 0.5286275148391724, 'high': 0.54053683065646, 'low': 0.5283844853164583, 'open': 0.5320301599449822, 'volume': 287972000}
# New record inserted successfully
# Index: 2015-09-08 00:00:00
# Pandas(Index=Timestamp('2015-09-08 00:00:00'), _1=0.5512309670448303, _2=0.5534184069237641, _3=0.5393217073579919, _4=0.5415090892899634, _5=238448000, _6=0.5286275148391724)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-08 00:00:00'), 'close': 0.5512309670448303, 'high': 0.5534184069237641, 'low': 0.5393217073579919, 'open': 0.5415090892899634, 'volume': 238448000}
# New record inserted successfully
# Index: 2015-09-09 00:00:00
# Pandas(Index=Timestamp('2015-09-09 00:00:00'), _1=0.5402938723564148, _2=0.5575501876298946, _3=0.5390786086887394, _4=0.5529323363548265, _5=289392000, _6=0.5512309670448303)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-09 00:00:00'), 'close': 0.5402938723564148, 'high': 0.5575501876298946, 'low': 0.5390786086887394, 'open': 0.5529323363548265, 'volume': 289392000}
# New record inserted successfully
# Index: 2015-09-10 00:00:00
# Pandas(Index=Timestamp('2015-09-10 00:00:00'), _1=0.5488003492355347, _2=0.5556056965922634, _3=0.534703653480866, _4=0.5371341222624949, _5=357076000, _6=0.5402938723564148)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-10 00:00:00'), 'close': 0.5488003492355347, 'high': 0.5556056965922634, 'low': 0.534703653480866, 'open': 0.5371341222624949, 'volume': 357076000}
# New record inserted successfully
# Index: 2015-09-11 00:00:00
# Pandas(Index=Timestamp('2015-09-11 00:00:00'), _1=0.550501823425293, _2=0.5541474982460478, _3=0.5405368591581862, _4=0.5427242988188129, _5=301584000, _6=0.5488003492355347)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-11 00:00:00'), 'close': 0.550501823425293, 'high': 0.5541474982460478, 'low': 0.5405368591581862, 'open': 0.5427242988188129, 'volume': 301584000}
# New record inserted successfully
# Index: 2015-09-14 00:00:00
# Pandas(Index=Timestamp('2015-09-14 00:00:00'), _1=0.5514736771583557, _2=0.5548763204546159, _3=0.5485570926490342, _4=0.5531749988064858, _5=192460000, _6=0.550501823425293)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-14 00:00:00'), 'close': 0.5514736771583557, 'high': 0.5548763204546159, 'low': 0.5485570926490342, 'open': 0.5531749988064858, 'volume': 192460000}
# New record inserted successfully
# Index: 2015-09-15 00:00:00
# Pandas(Index=Timestamp('2015-09-15 00:00:00'), _1=0.5575500130653381, _2=0.5604665985970303, _3=0.5500155777043908, _4=0.5517168999488968, _5=327976000, _6=0.5514736771583557)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-15 00:00:00'), 'close': 0.5575500130653381, 'high': 0.5604665985970303, 'low': 0.5500155777043908, 'open': 0.5517168999488968, 'volume': 327976000}
# New record inserted successfully
# Index: 2015-09-16 00:00:00
# Pandas(Index=Timestamp('2015-09-16 00:00:00'), _1=0.5614390969276428, _2=0.5645987137527574, _3=0.5524463636357692, _4=0.5565781568808476, _5=173508000, _6=0.5575500130653381)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-16 00:00:00'), 'close': 0.5614390969276428, 'high': 0.5645987137527574, 'low': 0.5524463636357692, 'open': 0.5565781568808476, 'volume': 173508000}
# New record inserted successfully
# Index: 2015-09-17 00:00:00
# Pandas(Index=Timestamp('2015-09-17 00:00:00'), _1=0.5665428638458252, _2=0.5762647394659095, _3=0.5653276004198399, _4=0.5711607142025006, _5=268712000, _6=0.5614390969276428)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-17 00:00:00'), 'close': 0.5665428638458252, 'high': 0.5762647394659095, 'low': 0.5653276004198399, 'open': 0.5711607142025006, 'volume': 268712000}
# New record inserted successfully
# Index: 2015-09-18 00:00:00
# Pandas(Index=Timestamp('2015-09-18 00:00:00'), _1=0.5660569071769714, _2=0.5709178463634909, _3=0.5553628525560218, _4=0.5587654983971923, _5=326412000, _6=0.5665428638458252)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-18 00:00:00'), 'close': 0.5660569071769714, 'high': 0.5709178463634909, 'low': 0.5553628525560218, 'open': 0.5587654983971923, 'volume': 326412000}
# New record inserted successfully
# Index: 2015-09-21 00:00:00
# Pandas(Index=Timestamp('2015-09-21 00:00:00'), _1=0.5718896985054016, _2=0.5731049615867906, _3=0.56386914759842, _4=0.5667857326362072, _5=281840000, _6=0.5660569071769714)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-21 00:00:00'), 'close': 0.5718896985054016, 'high': 0.5731049615867906, 'low': 0.56386914759842, 'open': 0.5667857326362072, 'volume': 281840000}
# New record inserted successfully
# Index: 2015-09-22 00:00:00
# Pandas(Index=Timestamp('2015-09-22 00:00:00'), _1=0.5563350319862366, _2=0.5633834112310971, _3=0.5534184452788553, _4=0.5594946482702442, _5=228356000, _6=0.5718896985054016)
# {'ticker': 'NVDA', 'date': Timestamp('2015-09-22 00:00:00'), 'close': 0.5563350319862366, 'high': 0.5633834112310971, 'low': 0.5534184452788553, 'open': 0.5594946482702442, 'volume': 228356000}
# New record inserted successfully
# Index: 2015-09-23 00:00:00
# Pandas(Index=Timestamp('2015-09-23 00:00:00'), _1=0.5590083599090576, _2=0.562411004727238, _3=0.5546335391352468, _4=0.5568209205486779, _5=161632000, _6=0.5563350319862366)
# ...
# {'ticker': 'NVDA', 'date': Timestamp('2025-02-20 00:00:00'), 'close': 140.0971221923828, 'high': 140.6470746897965, 'low': 136.7774200315485, 'open': 140.01712771481476, 'volume': 143903600}
# New record inserted successfully
# Index: 2025-02-21 00:00:00
# Pandas(Index=Timestamp('2025-02-21 00:00:00'), _1=134.41763305664062, _2=141.4470007486669, _3=134.01767593596887, _4=140.02711787829398, _5=228217600, _6=140.0971221923828)
# {'ticker': 'NVDA', 'date': Timestamp('2025-02-21 00:00:00'), 'close': 134.41763305664062, 'high': 141.4470007486669, 'low': 134.01767593596887, 'open': 140.02711787829398, 'volume': 228217600}
# New record inserted successfully
# Index: 2025-02-24 00:00:00
# Pandas(Index=Timestamp('2025-02-24 00:00:00'), _1=130.2680206298828, _2=138.57725415414035, _3=130.06804206967678, _4=136.5474420161462, _5=251381100, _6=134.41763305664062)
# {'ticker': 'NVDA', 'date': Timestamp('2025-02-24 00:00:00'), 'close': 130.2680206298828, 'high': 138.57725415414035, 'low': 130.06804206967678, 'open': 136.5474420161462, 'volume': 251381100}
# New record inserted successfully
# Index: 2025-02-25 00:00:00
# Pandas(Index=Timestamp('2025-02-25 00:00:00'), _1=126.61835479736328, _2=130.18802626376245, _3=124.42856133510212, _4=129.96804527013506, _5=271428700, _6=130.2680206298828)
# {'ticker': 'NVDA', 'date': Timestamp('2025-02-25 00:00:00'), 'close': 126.61835479736328, 'high': 130.18802626376245, 'low': 124.42856133510212, 'open': 129.96804527013506, 'volume': 271428700}
# New record inserted successfully
# Index: 2025-02-26 00:00:00
# Pandas(Index=Timestamp('2025-02-26 00:00:00'), _1=131.26792907714844, _2=133.71770077604796, _3=128.478192299153, _4=129.97805439122038, _5=322553800, _6=126.61835479736328)
# {'ticker': 'NVDA', 'date': Timestamp('2025-02-26 00:00:00'), 'close': 131.26792907714844, 'high': 133.71770077604796, 'low': 128.478192299153, 'open': 129.97805439122038, 'volume': 322553800}
# New record inserted successfully
# Index: 2025-02-27 00:00:00
# Pandas(Index=Timestamp('2025-02-27 00:00:00'), _1=120.13895416259766, _2=134.99758082030266, _3=119.99896764539281, _4=134.9875872324259, _5=443175800, _6=131.26792907714844)
# {'ticker': 'NVDA', 'date': Timestamp('2025-02-27 00:00:00'), 'close': 120.13895416259766, 'high': 134.99758082030266, 'low': 119.99896764539281, 'open': 134.9875872324259, 'volume': 443175800}
# New record inserted successfully
# Index: 2025-02-28 00:00:00
# Pandas(Index=Timestamp('2025-02-28 00:00:00'), _1=124.90850830078125, _2=125.07849083366686, _3=116.38929530836823, _4=118.00914142194866, _5=389091100, _6=120.13895416259766)
# {'ticker': 'NVDA', 'date': Timestamp('2025-02-28 00:00:00'), 'close': 124.90850830078125, 'high': 125.07849083366686, 'low': 116.38929530836823, 'open': 118.00914142194866, 'volume': 389091100}
# New record inserted successfully
# Index: 2025-03-03 00:00:00
# Pandas(Index=Timestamp('2025-03-03 00:00:00'), _1=114.04950714111328, _2=123.68861991301428, _3=112.26967207329028, _4=123.49864257535764, _5=411381400, _6=124.90850830078125)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-03 00:00:00'), 'close': 114.04950714111328, 'high': 123.68861991301428, 'low': 112.26967207329028, 'open': 123.49864257535764, 'volume': 411381400}
# New record inserted successfully
# Index: 2025-03-04 00:00:00
# Pandas(Index=Timestamp('2025-03-04 00:00:00'), _1=115.97933197021484, _2=119.29902637351395, _3=110.09987541363249, _4=110.63982667322061, _5=398163300, _6=114.04950714111328)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-04 00:00:00'), 'close': 115.97933197021484, 'high': 119.29902637351395, 'low': 110.09987541363249, 'open': 110.63982667322061, 'volume': 398163300}
# New record inserted successfully
# Index: 2025-03-05 00:00:00
# Pandas(Index=Timestamp('2025-03-05 00:00:00'), _1=117.28921508789062, _2=118.26912068620358, _3=114.49947076595478, _4=117.56918811598004, _5=284337900, _6=115.97933197021484)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-05 00:00:00'), 'close': 117.28921508789062, 'high': 118.26912068620358, 'low': 114.49947076595478, 'open': 117.56918811598004, 'volume': 284337900}
# New record inserted successfully
# Index: 2025-03-06 00:00:00
# Pandas(Index=Timestamp('2025-03-06 00:00:00'), _1=110.55982971191406, _2=115.3393888375433, _3=110.209863429875, _4=113.51955654224739, _5=321181900, _6=117.28921508789062)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-06 00:00:00'), 'close': 110.55982971191406, 'high': 115.3393888375433, 'low': 110.209863429875, 'open': 113.51955654224739, 'volume': 321181900}
# New record inserted successfully
# Index: 2025-03-07 00:00:00
# Pandas(Index=Timestamp('2025-03-07 00:00:00'), _1=112.67964172363281, _2=113.46957000648335, _3=107.5501084934214, _4=111.2397716760376, _5=341755500, _6=110.55982971191406)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-07 00:00:00'), 'close': 112.67964172363281, 'high': 113.46957000648335, 'low': 107.5501084934214, 'open': 111.2397716760376, 'volume': 341755500}
# New record inserted successfully
# Index: 2025-03-10 00:00:00
# Pandas(Index=Timestamp('2025-03-10 00:00:00'), _1=106.97016143798828, _2=111.83970852661247, _3=105.45029700249104, _4=109.88989097369002, _5=366487400, _6=112.67964172363281)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-10 00:00:00'), 'close': 106.97016143798828, 'high': 111.83970852661247, 'low': 105.45029700249104, 'open': 109.88989097369002, 'volume': 366487400}
# New record inserted successfully
# Index: 2025-03-11 00:00:00
# Pandas(Index=Timestamp('2025-03-11 00:00:00'), _1=108.75, _2=112.22967568900775, _3=104.76036144852146, _4=106.98015850635034, _5=354865700, _6=106.97016143798828)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-11 00:00:00'), 'close': 108.75, 'high': 112.22967568900775, 'low': 104.76036144852146, 'open': 106.98015850635034, 'volume': 354865700}
# New record inserted successfully
# Index: 2025-03-12 00:00:00
# Pandas(Index=Timestamp('2025-03-12 00:00:00'), _1=115.73999786376953, _2=116.76000213623047, _3=112.87999725341797, _4=114.12000274658203, _5=323857500, _6=108.75)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-12 00:00:00'), 'close': 115.73999786376953, 'high': 116.76000213623047, 'low': 112.87999725341797, 'open': 114.12000274658203, 'volume': 323857500}
# New record inserted successfully
# Index: 2025-03-13 00:00:00
# Pandas(Index=Timestamp('2025-03-13 00:00:00'), _1=115.58000183105469, _2=117.76000213623047, _3=113.79000091552734, _4=117.02999877929688, _5=299033100, _6=115.73999786376953)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-13 00:00:00'), 'close': 115.58000183105469, 'high': 117.76000213623047, 'low': 113.79000091552734, 'open': 117.02999877929688, 'volume': 299033100}
# New record inserted successfully
# Index: 2025-03-14 00:00:00
# Pandas(Index=Timestamp('2025-03-14 00:00:00'), _1=121.66999816894531, _2=121.87999725341797, _3=118.1500015258789, _4=118.61000061035156, _5=277593500, _6=115.58000183105469)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-14 00:00:00'), 'close': 121.66999816894531, 'high': 121.87999725341797, 'low': 118.1500015258789, 'open': 118.61000061035156, 'volume': 277593500}
# New record inserted successfully
# Index: 2025-03-17 00:00:00
# Pandas(Index=Timestamp('2025-03-17 00:00:00'), _1=119.52999877929688, _2=122.88999938964844, _3=118.02999877929688, _4=122.73999786376953, _5=255501500, _6=121.66999816894531)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-17 00:00:00'), 'close': 119.52999877929688, 'high': 122.88999938964844, 'low': 118.02999877929688, 'open': 122.73999786376953, 'volume': 255501500}
# New record inserted successfully
# Index: 2025-03-18 00:00:00
# Pandas(Index=Timestamp('2025-03-18 00:00:00'), _1=115.43000030517578, _2=119.0199966430664, _3=114.54000091552734, _4=118.0, _5=299686900, _6=119.52999877929688)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-18 00:00:00'), 'close': 115.43000030517578, 'high': 119.0199966430664, 'low': 114.54000091552734, 'open': 118.0, 'volume': 299686900}
# New record inserted successfully
# Index: 2025-03-19 00:00:00
# Pandas(Index=Timestamp('2025-03-19 00:00:00'), _1=117.5199966430664, _2=120.44999694824219, _3=115.68000030517578, _4=117.2699966430664, _5=273426200, _6=115.43000030517578)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-19 00:00:00'), 'close': 117.5199966430664, 'high': 120.44999694824219, 'low': 115.68000030517578, 'open': 117.2699966430664, 'volume': 273426200}
# New record inserted successfully
# Index: 2025-03-20 00:00:00
# Pandas(Index=Timestamp('2025-03-20 00:00:00'), _1=118.52999877929688, _2=120.19999694824219, _3=116.47000122070312, _4=116.55000305175781, _5=248829700, _6=117.5199966430664)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-20 00:00:00'), 'close': 118.52999877929688, 'high': 120.19999694824219, 'low': 116.47000122070312, 'open': 116.55000305175781, 'volume': 248829700}
# New record inserted successfully
# Index: 2025-03-21 00:00:00
# Pandas(Index=Timestamp('2025-03-21 00:00:00'), _1=117.69999694824219, _2=117.98999786376953, _3=115.41999816894531, _4=116.94000244140625, _5=266498500, _6=118.52999877929688)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-21 00:00:00'), 'close': 117.69999694824219, 'high': 117.98999786376953, 'low': 115.41999816894531, 'open': 116.94000244140625, 'volume': 266498500}
# New record inserted successfully
# Index: 2025-03-24 00:00:00
# Pandas(Index=Timestamp('2025-03-24 00:00:00'), _1=121.41000366210938, _2=122.22000122070312, _3=119.33999633789062, _4=119.87999725341797, _5=228452500, _6=117.69999694824219)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-24 00:00:00'), 'close': 121.41000366210938, 'high': 122.22000122070312, 'low': 119.33999633789062, 'open': 119.87999725341797, 'volume': 228452500}
# New record inserted successfully
# Index: 2025-03-25 00:00:00
# Pandas(Index=Timestamp('2025-03-25 00:00:00'), _1=120.69000244140625, _2=121.29000091552734, _3=118.91999816894531, _4=120.55000305175781, _5=167447200, _6=121.41000366210938)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-25 00:00:00'), 'close': 120.69000244140625, 'high': 121.29000091552734, 'low': 118.91999816894531, 'open': 120.55000305175781, 'volume': 167447200}
# New record inserted successfully
# Index: 2025-03-26 00:00:00
# Pandas(Index=Timestamp('2025-03-26 00:00:00'), _1=113.76000213623047, _2=118.83999633789062, _3=112.70999908447266, _4=118.7300033569336, _5=293463300, _6=120.69000244140625)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-26 00:00:00'), 'close': 113.76000213623047, 'high': 118.83999633789062, 'low': 112.70999908447266, 'open': 118.7300033569336, 'volume': 293463300}
# New record inserted successfully
# Index: 2025-03-27 00:00:00
# Pandas(Index=Timestamp('2025-03-27 00:00:00'), _1=111.43000030517578, _2=114.44999694824219, _3=110.66000366210938, _4=111.3499984741211, _5=236902100, _6=113.76000213623047)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-27 00:00:00'), 'close': 111.43000030517578, 'high': 114.44999694824219, 'low': 110.66000366210938, 'open': 111.3499984741211, 'volume': 236902100}
# New record inserted successfully
# Index: 2025-03-28 00:00:00
# Pandas(Index=Timestamp('2025-03-28 00:00:00'), _1=109.66999816894531, _2=112.87000274658203, _3=109.06999969482422, _4=111.48999786376953, _5=229872500, _6=111.43000030517578)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-28 00:00:00'), 'close': 109.66999816894531, 'high': 112.87000274658203, 'low': 109.06999969482422, 'open': 111.48999786376953, 'volume': 229872500}
# New record inserted successfully
# Index: 2025-03-31 00:00:00
# Pandas(Index=Timestamp('2025-03-31 00:00:00'), _1=108.37999725341797, _2=110.95999908447266, _3=103.6500015258789, _4=105.12999725341797, _5=299212700, _6=109.66999816894531)
# {'ticker': 'NVDA', 'date': Timestamp('2025-03-31 00:00:00'), 'close': 108.37999725341797, 'high': 110.95999908447266, 'low': 103.6500015258789, 'open': 105.12999725341797, 'volume': 299212700}
# New record inserted successfully
# Index: 2025-04-01 00:00:00
# Pandas(Index=Timestamp('2025-04-01 00:00:00'), _1=110.1500015258789, _2=110.19999694824219, _3=106.47000122070312, _4=108.5199966430664, _5=222614000, _6=108.37999725341797)
# {'ticker': 'NVDA', 'date': Timestamp('2025-04-01 00:00:00'), 'close': 110.1500015258789, 'high': 110.19999694824219, 'low': 106.47000122070312, 'open': 108.5199966430664, 'volume': 222614000}
# New record inserted successfully
# Index: 2025-04-02 00:00:00
# Pandas(Index=Timestamp('2025-04-02 00:00:00'), _1=110.41999816894531, _2=111.9800033569336, _3=106.79000091552734, _4=107.29000091552734, _5=220601200, _6=110.1500015258789)
# {'ticker': 'NVDA', 'date': Timestamp('2025-04-02 00:00:00'), 'close': 110.41999816894531, 'high': 111.9800033569336, 'low': 106.79000091552734, 'open': 107.29000091552734, 'volume': 220601200}
# New record inserted successfully
# Index: 2025-04-03 00:00:00
# Pandas(Index=Timestamp('2025-04-03 00:00:00'), _1=101.80000305175781, _2=105.62999725341797, _3=101.5999984741211, _4=103.51000213623047, _5=338769400, _6=110.41999816894531)
# {'ticker': 'NVDA', 'date': Timestamp('2025-04-03 00:00:00'), 'close': 101.80000305175781, 'high': 105.62999725341797, 'low': 101.5999984741211, 'open': 103.51000213623047, 'volume': 338769400}
# New record inserted successfully
# Index: 2025-04-04 00:00:00
# Pandas(Index=Timestamp('2025-04-04 00:00:00'), _1=94.30999755859375, _2=100.12999725341797, _3=92.11000061035156, _4=98.91000366210938, _5=532273800, _6=101.80000305175781)
# {'ticker': 'NVDA', 'date': Timestamp('2025-04-04 00:00:00'), 'close': 94.30999755859375, 'high': 100.12999725341797, 'low': 92.11000061035156, 'open': 98.91000366210938, 'volume': 532273800}
# New record inserted successfully
# Index: 2025-04-07 00:00:00
# Pandas(Index=Timestamp('2025-04-07 00:00:00'), _1=97.63999938964844, _2=101.75, _3=86.62000274658203, _4=87.45999908447266, _5=611041300, _6=94.30999755859375)
# {'ticker': 'NVDA', 'date': Timestamp('2025-04-07 00:00:00'), 'close': 97.63999938964844, 'high': 101.75, 'low': 86.62000274658203, 'open': 87.45999908447266, 'volume': 611041300}
# New record inserted successfully
# Index: 2025-04-08 00:00:00
# Pandas(Index=Timestamp('2025-04-08 00:00:00'), _1=96.30000305175781, _2=105.8499984741211, _3=94.45999908447266, _4=103.80999755859375, _5=476243400, _6=97.63999938964844)
# {'ticker': 'NVDA', 'date': Timestamp('2025-04-08 00:00:00'), 'close': 96.30000305175781, 'high': 105.8499984741211, 'low': 94.45999908447266, 'open': 103.80999755859375, 'volume': 476243400}
# New record inserted successfully
# Index: 2025-04-09 00:00:00
# Pandas(Index=Timestamp('2025-04-09 00:00:00'), _1=114.33000183105469, _2=115.0999984741211, _3=97.52999877929688, _4=98.88999938964844, _5=612918300, _6=96.30000305175781)
# {'ticker': 'NVDA', 'date': Timestamp('2025-04-09 00:00:00'), 'close': 114.33000183105469, 'high': 115.0999984741211, 'low': 97.52999877929688, 'open': 98.88999938964844, 'volume': 612918300}
# New record inserted successfully
# Index: 2025-04-10 00:00:00
# Pandas(Index=Timestamp('2025-04-10 00:00:00'), _1=107.56999969482422, _2=110.86000061035156, _3=99.1500015258789, _4=109.37000274658203, _5=437812400, _6=114.33000183105469)
# {'ticker': 'NVDA', 'date': Timestamp('2025-04-10 00:00:00'), 'close': 107.56999969482422, 'high': 110.86000061035156, 'low': 99.1500015258789, 'open': 109.37000274658203, 'volume': 437812400}
# New record inserted successfully
# Index: 2025-04-11 00:00:00
# Pandas(Index=Timestamp('2025-04-11 00:00:00'), _1=110.93000030517578, _2=111.55000305175781, _3=107.4800033569336, _4=108.5, _5=312853800, _6=107.56999969482422)
# {'ticker': 'NVDA', 'date': Timestamp('2025-04-11 00:00:00'), 'close': 110.93000030517578, 'high': 111.55000305175781, 'low': 107.4800033569336, 'open': 108.5, 'volume': 312853800}
# New record inserted successfully
# Index: 2025-04-14 00:00:00
# Pandas(Index=Timestamp('2025-04-14 00:00:00'), _1=110.70999908447266, _2=114.29000091552734, _3=109.06999969482422, _4=114.13999938964844, _5=259339786, _6=110.93000030517578)
# {'ticker': 'NVDA', 'date': Timestamp('2025-04-14 00:00:00'), 'close': 110.70999908447266, 'high': 114.29000091552734, 'low': 109.06999969482422, 'open': 114.13999938964844, 'volume': 259339786}
# New record inserted successfully

# %% [markdown]
# ##### XGBoost Model

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# Fetch historical data
def get_stock_data():
    ticker = "NVDA"
    df = yf.download(ticker, period='120mo', interval='1d')
    df = df[['Close']].copy()
    df.columns = ['close']
    
    # Create features
    df['prev_close'] = df['close'].shift(1)
    df['sma_5'] = df['close'].rolling(window=5).mean()
    df['sma_10'] = df['close'].rolling(window=10).mean()
    df['daily_return'] = df['close'].pct_change()
    df.dropna(inplace=True)
    return df

# %%
# Prepare data for modeling
def prepare_data(df):
    # Create target (next day's closing price)
    df['target'] = df['close'].shift(-1)
    df.dropna(inplace=True)
    
    X = df.drop(['target'], axis=1)
    y = df['target']

# %%
# Prepare data for modeling
def prepare_data(df):
    # Create target (next day's closing price)
    df['target'] = df['close'].shift(-1)
    df.dropna(inplace=True)
    
    X = df.drop(['target'], axis=1)
    y = df['target']
    
    # Scale features
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Split data
    X_train, X_test, y_train, y_test = train_test_split(
        X_scaled, y, test_size=0.2, shuffle=False)
    
    return X_train, X_test, y_train, y_test, scaler, X, y

# %%
# Train models and evaluate
def train_and_evaluate(X_train, X_test, y_train, y_test):
    models = {
        
        'XGBoost': XGBRegressor(n_estimators=100, random_state=42)
    }
    
    results = {}
    
    for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        results[name] = {
            'model': model,
            'r2_score': r2,
            'predictions': y_pred
        }
        print(f"{name} R-squared: {r2:.4f}")
    
    return results

# Make prediction for tomorrow
def predict_tomorrow(models, df, scaler):
    # Prepare most recent data point
    last_data = df.iloc[-1:].drop(['target'], axis=1)
    last_data_scaled = scaler.transform(last_data)
    
    predictions = {}
    tomorrow_date = (datetime.now() + timedelta(days=1)).strftime('%Y-%m-%d')
    
    for name, result in models.items():
        pred_price = result['model'].predict(last_data_scaled)[0]
        predictions[name] = {
            'date': tomorrow_date,
            'predicted_price': round(pred_price, 2),
            'model': name,
            'r2_score': result['r2_score']
        }
    
    return pd.DataFrame.from_dict(predictions, orient='index')

# Main execution
if __name__ == "__main__":
    # Get and prepare data
    df = get_stock_data()
    X_train, X_test, y_train, y_test, scaler, X, y = prepare_data(df)
    
    # Train and evaluate models
    model_results = train_and_evaluate(X_train, X_test, y_train, y_test)
    
    # Make tomorrow's prediction
    tomorrow_pred = predict_tomorrow(model_results, df, scaler)
    print("\nTomorrow's Predictions:")
    print(tomorrow_pred[['date', 'predicted_price', 'r2_score']])
    
    # Save predictions to database (using your existing code)
    try:
        with pyodbc.connect(r'DRIVER={ODBC Driver 17 for SQL Server};SERVER=localhost;DATABASE=stock_market;Trusted_Connection=yes;') as conn:
            cursor = conn.cursor()
            
            for index, row in tomorrow_pred.iterrows():
                cursor.execute("""
                    INSERT INTO StockPredictions (Ticker, Date, Model, PredictedPrice, R2Score)
                    VALUES (?, ?, ?, ?, ?)
                """, 'NVDA', row['date'], row['model'], row['predicted_price'], row['r2_score'])
                
            conn.commit()
            print("Predictions saved to database successfully")
            
    except pyodbc.Error as e:
        print(f"Database error: {e}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# XGBoost R-squared: -1.9783
#
# Tomorrow's Predictions:
#                date  predicted_price  r2_score
# XGBoost  2025-04-15        32.200001 -1.978267
# Predictions saved to database successfully

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Step 1: Create target - tomorrow's close
df['Target'] = df[('Close', 'NVDA')].shift(-1)
df.dropna(inplace=True)  # Remove the last row with NaN target

# Step 2: Feature engineering - basic features
df['Return'] = df[('Close', 'NVDA')].pct_change()
df['Volatility'] = df['Return'].rolling(window=5).std()
df['Volume_Change'] = df[('Volume', 'NVDA')].pct_change()
df['Price_Range'] = df[('High', 'NVDA')] - df[('Low', 'NVDA')]

df.dropna(inplace=True)

# Features and target
features = ['Return', 'Volatility', 'Volume_Change', 'Price_Range']
X = df[features]
y = df['Target']

# Step 3: Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)

# Step 4: Train XGBoost
model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, learning_rate=0.1)
model.fit(X_train, y_train)

# Step 5: Evaluate model
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")

# Step 6: Predict tomorrow’s close
latest = df[features].iloc[-1:]
predicted_close = model.predict(latest)
print(f"Predicted close for tomorrow: ${predicted_close[0]:.2f}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Close', 'NVDA')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 6
#       3 from sklearn.metrics import mean_squared_error, r2_score
#       5 # Step 1: Create target - tomorrow's close
# ----> 6 df['Target'] = df[('Close', 'NVDA')].shift(-1)
#       7 df.dropna(inplace=True)  # Remove the last row with NaN target
#       9 # Step 2: Feature engineering - basic features
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: ('Close', 'NVDA')
